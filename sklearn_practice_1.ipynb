# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
Datapath = r"E:\Monali\Class\Datasets\archive\geoplaces2.csv"
X_df = pd.read_csv(Datapath)
X_df
# Out:
#      placeID   latitude   longitude  \
# 0     134999  18.915421  -99.184871
# 1     132825  22.147392 -100.983092
# 2     135106  22.149709 -100.976093
# 3     132667  23.752697  -99.163359
# 4     132613  23.752903  -99.165076
# ..       ...        ...         ...
# 125   132866  22.141220 -100.931311
# 126   135072  22.149192 -101.002936
# 127   135109  18.921785  -99.235350
# 128   135019  18.875011  -99.159422
# 129   132877  22.135364 -100.934948
#
#                                         the_geom_meter  \
# 0    0101000020957F000088568DE356715AC138C0A525FC46...
# 1    0101000020957F00001AD016568C4858C1243261274BA5...
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3    0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4    0101000020957F00008EBA2D06DC8157C194E03B7B504E...
# ..                                                 ...
# 125  0101000020957F000013871838EC4A58C1B5DF74F8E396...
# 126  0101000020957F0000E7B79B1DB94758C1D29BC363D8AA...
# ...

# %%
X_df.shape
# Out:
# (130, 21)

# %%
X_df.isnull()
# Out:
#      placeID  latitude  longitude  the_geom_meter   name  address   city  \
# 0      False     False      False           False  False    False  False
# 1      False     False      False           False  False    False  False
# 2      False     False      False           False  False    False  False
# 3      False     False      False           False  False    False  False
# 4      False     False      False           False  False    False  False
# ..       ...       ...        ...             ...    ...      ...    ...
# 125    False     False      False           False  False    False  False
# 126    False     False      False           False  False    False  False
# 127    False     False      False           False  False    False  False
# 128    False     False      False           False  False    False  False
# 129    False     False      False           False  False    False  False
#
#      state  country    fax  ...  alcohol  smoking_area  dress_code  \
# ...

# %% [markdown]
# # handling null values

# %%
num_Xvars =X_df.select_dtypes(include=["int64","float64"]).columns
num_Xvars
# Out:
# Index(['placeID', 'latitude', 'longitude'], dtype='object')

# %%
X_df.isnull().sum()
# Out:
# placeID           0
# latitude          0
# longitude         0
# the_geom_meter    0
# name              0
# address           0
# city              0
# state             0
# country           0
# fax               0
# zip               0
# alcohol           0
# smoking_area      0
# dress_code        0
# accessibility     0
# price             0
# url               0
# Rambience         0
# franchise         0
# area              0
# other_services    0
# dtype: int64

# %% [markdown]
# # example 2

# %%
y_df = pd.read_csv(r"E:\Monali\Class\Datasets\archive\india-news-headlines.csv")
y_df
# Out:
#          publish_date                  headline_category  \
# 0            20010102                            unknown
# 1            20010102                            unknown
# 2            20010102                            unknown
# 3            20010102                            unknown
# 4            20010102                            unknown
# ...               ...                                ...
# 3424062      20201231                       city.jodhpur
# 3424063      20201231                       city.udaipur
# 3424064      20201231                         city.ajmer
# 3424065      20201231                            removed
# 3424066      20201231  entertainment.bengali.movies.news
#
#                                              headline_text
# 0        Status quo will not be disturbed at Ayodhya; s...
# 1                      Fissures in Hurriyat over Pak visit
# 2                    America's unwanted heading for India?
# ...

# %%
y_df.shape
# Out:
# (3424067, 3)

# %%
y_df.isnull()
# Out:
#          publish_date  headline_category  headline_text
# 0               False              False          False
# 1               False              False          False
# 2               False              False          False
# 3               False              False          False
# 4               False              False          False
# ...               ...                ...            ...
# 3424062         False              False          False
# 3424063         False              False          False
# 3424064         False              False          False
# 3424065         False              False          False
# 3424066         False              False          False
#
# [3424067 rows x 3 columns]

# %%
num_yvars =y_df.select_dtypes(include=["int64","float64"]).columns
num_yvars
# Out:
# Index(['publish_date'], dtype='object')

# %%
y_df.isnull()
# Out:
#          publish_date  headline_category  headline_text
# 0               False              False          False
# 1               False              False          False
# 2               False              False          False
# 3               False              False          False
# 4               False              False          False
# ...               ...                ...            ...
# 3424062         False              False          False
# 3424063         False              False          False
# 3424064         False              False          False
# 3424065         False              False          False
# 3424066         False              False          False
#
# [3424067 rows x 3 columns]

# %%
y_df.isnull().sum()
# Out:
# publish_date         0
# headline_category    0
# headline_text        0
# dtype: int64

# %%
cat_yvars = y_df.select_dtypes(include=["O"]).columns
cat_yvars
# Out:
# Index(['headline_category', 'headline_text'], dtype='object')

# %%
cat_yvars.isnull()
# Out:
# array([False, False])

# %%
cat_yvars.isnull().sum()
# Out:
# 0

# %% [markdown]
# # example 3

# %%
a_df = pd.read_csv(r"E:\Monali\Class\Datasets\archive\Mall_Customers.csv")
a_df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
a_df.shape
# Out:
# (200, 5)

# %%
a_df.isnull()
# Out:
#      CustomerID  Genre    Age  Annual Income (k$)  Spending Score (1-100)
# 0         False  False  False               False                   False
# 1         False  False  False               False                   False
# 2         False  False  False               False                   False
# 3         False  False  False               False                   False
# 4         False  False  False               False                   False
# ..          ...    ...    ...                 ...                     ...
# 195       False  False  False               False                   False
# 196       False  False  False               False                   False
# 197       False  False  False               False                   False
# 198       False  False  False               False                   False
# 199       False  False  False               False                   False
#
# [200 rows x 5 columns]

# %%
a_df.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
a_df.isnull().sum().sum()
# Out:
# 0
